# %%
from ultralytics import YOLO

# Load a model
model = YOLO('best.pt')

# %%
results = model(source='video1.mp4', show=True, conf=0.6, save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/500) c:\ilham files\codes\viskom\mid-semester_project\object-detection-tf\video1.mp4: 384x640 (no detections), 91.1ms
# video 1/1 (2/500) c:\ilham files\codes\viskom\mid-semester_project\object-detection-tf\video1.mp4: 384x640 (no detections), 43.4ms
# video 1/1 (3/500) c:\ilham files\codes\viskom\mid-semester_project\object-detection-tf\video1.mp4: 384x640 (no detections), 39.9ms
# ...
